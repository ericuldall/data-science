# %% [markdown]
# #Things and stuff

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([0, 10, 20], [0, 10, 0])

# %%
s = pd.Series(data=[1, 2, 3, 4], index=['first', 'second', 'third', 'fourth'])
s2= pd.Series(data=[3, 4, 5, 6], index=['third', 'fourth', 'fifth', 'sixth'])
s + s2
# Out:
# fifth    NaN
# first    NaN
# fourth     8
# second   NaN
# sixth    NaN
# third      6
# dtype: float64

# %%
s['first']
# Out:
# 1

# %%
df = pd.DataFrame({'state': ['California', 'New York', 'Texas'], 'party': ['D', 'D', 'R']})
df
# Out:
#   party       state
# 0     D  California
# 1     D    New York
# 2     R       Texas

# %%
df[0:1]
# Out:
# <bound method DataFrame.boxplot of   party       state
# 0     D  California
# 1     D    New York
# 2     R       Texas>

# %%
df = pd.read_csv("../knn/athletes.clean.csv")

# %%
df
# Out:
#                                   Name                     Country  Age  \
# 0                             Lamusi A  People's Republic of China   23
# 1                           A G Kruger    United States of America   33
# 2                       Jamale Aarrass                      France   30
# 3                     Abdelhak Aatakni                     Morocco   24
# 4                      Maria Abakumova          Russian Federation   26
# 5                            Luc Abalo                      France   27
# 6                    Maria Laura Abalo                   Argentina   30
# 7                     Mohamed Abarhoun                     Morocco   23
# 8                       Emanuele Abate                       Italy   27
# 9                         Ilyas Abbadi                     Algeria   19
# 10                        Sohail Abbas                    Pakistan   37
# 11                      Shakeel Abbasi                    Pakistan   28
# ...

# %%
df.Age
# Out:
# 0     23
# 1     33
# 2     30
# 3     24
# 4     26
# 5     27
# 6     30
# 7     23
# 8     27
# 9     19
# 10    37
# 11    28
# 12    28
# 13    28
# 14    22
# ...
# 10369    29
# 10370    27
# 10371    24
# 10372    25
# 10373    22
# 10374    25
# 10375    24
# 10376    27
# 10377    24
# 10378    19
# 10379    24
# 10380    28
# 10381    27
# 10382    25
# 10383    24
# Name: Age, Length: 10384, dtype: int64

# %%
df.T
# Out:
#                                      0                         1      \
# Name                              Lamusi A                A G Kruger
# Country         People's Republic of China  United States of America
# Age                                     23                        33
# Height, cm                             170                       193
# Weight                                  60                       125
# Sex                                      M                         M
# Date of birth                     6/2/1989                 2/18/1979
# Place of birth            NEIMONGGOL (CHN)             Sheldon (USA)
# Gold                                     0                         0
# Silver                                   0                         0
# Bronze                                   0                         0
# Total                                    0                         0
# Sport                                 Judo                 Athletics
# ...

# %%
df.drop_duplicates
# Out:
# <bound method DataFrame.drop_duplicates of                                   Name                     Country  Age  \
# 0                             Lamusi A  People's Republic of China   23
# 1                           A G Kruger    United States of America   33
# 2                       Jamale Aarrass                      France   30
# 3                     Abdelhak Aatakni                     Morocco   24
# 4                      Maria Abakumova          Russian Federation   26
# 5                            Luc Abalo                      France   27
# 6                    Maria Laura Abalo                   Argentina   30
# 7                     Mohamed Abarhoun                     Morocco   23
# 8                       Emanuele Abate                       Italy   27
# 9                         Ilyas Abbadi                     Algeria   19
# 10                        Sohail Abbas                    Pakistan   37
# ...

# %%
# Out:
#                                   Name                     Country  Age  \
# 0                             Lamusi A  People's Republic of China   23
# 1                           A G Kruger    United States of America   33
# 2                       Jamale Aarrass                      France   30
# 3                     Abdelhak Aatakni                     Morocco   24
# 4                      Maria Abakumova          Russian Federation   26
# 5                            Luc Abalo                      France   27
# 6                    Maria Laura Abalo                   Argentina   30
# 7                     Mohamed Abarhoun                     Morocco   23
# 8                       Emanuele Abate                       Italy   27
# 9                         Ilyas Abbadi                     Algeria   19
# 10                        Sohail Abbas                    Pakistan   37
# 11                      Shakeel Abbasi                    Pakistan   28
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10384 entries, 0 to 10383
# Data columns (total 14 columns):
# Name              10384 non-null object
# Country           10384 non-null object
# Age               10384 non-null int64
# Height, cm        9823 non-null float64
# Weight            9104 non-null float64
# Sex               10384 non-null object
# Date of birth     10384 non-null object
# Place of birth    7694 non-null object
# Gold              10384 non-null int64
# Silver            10384 non-null int64
# Bronze            10384 non-null int64
# Total             10384 non-null int64
# Sport             10384 non-null object
# Event             10384 non-null object
# dtypes: float64(2), int64(5), object(7)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#                 Age   Height, cm       Weight          Gold        Silver  \
# count  10384.000000  9823.000000  9104.000000  10384.000000  10384.000000
# mean      26.068856   176.907869    72.852812      0.016660      0.017045
# std        5.440561    11.295433    16.067462      0.136026      0.133115
# min       13.000000   132.000000    36.000000      0.000000      0.000000
# 25%       22.000000   169.000000    61.000000      0.000000      0.000000
# 50%       25.000000   177.000000    70.000000      0.000000      0.000000
# 75%       29.000000   185.000000    81.000000      0.000000      0.000000
# max       71.000000   221.000000   218.000000      2.000000      2.000000
#
#              Bronze         Total
# count  10384.000000  10384.000000
# mean       0.018490      0.052196
# std        0.136144      0.250149
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# ...

# %%
df.describe()
# Out:
#                 Age   Height, cm       Weight          Gold        Silver  \
# count  10384.000000  9823.000000  9104.000000  10384.000000  10384.000000
# mean      26.068856   176.907869    72.852812      0.016660      0.017045
# std        5.440561    11.295433    16.067462      0.136026      0.133115
# min       13.000000   132.000000    36.000000      0.000000      0.000000
# 25%       22.000000   169.000000    61.000000      0.000000      0.000000
# 50%       25.000000   177.000000    70.000000      0.000000      0.000000
# 75%       29.000000   185.000000    81.000000      0.000000      0.000000
# max       71.000000   221.000000   218.000000      2.000000      2.000000
#
#              Bronze         Total
# count  10384.000000  10384.000000
# mean       0.018490      0.052196
# std        0.136144      0.250149
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      0.000000
# ...

# %%
df[(df["Age"] > 50) | (df["Age"] < 20)][["Sport", "Age"]].describe()
# Out:
#               Age
# count  831.000000
# mean    19.078219
# std      6.504671
# min     13.000000
# 25%     17.000000
# 50%     18.000000
# 75%     19.000000
# max     71.000000

# %%
#df.fillna(df.mean())
df
men = df[df["Sex"] == "M"]
women = df[df["Sex"] == "F"]

(men["Height, cm"]).hist(bins=30, color='#333666')
(women["Height, cm"]).hist(bins=30, alpha=0.5, color='#ffffcc')
#plt.title('Num Athletes x Weight')
